# %%
# import pandas as pd

def post_lisbon_dircode_mapper(df):
    
    """takes column in pandas dataframe with the pre-Lisbon case law directory classification scheme and assigns post-Lisbon codes, where applicable"""
    
    df.loc[df["target_col"] == "a-01", "target_col"] = "1.01" # Sources of EU law
    df.loc[df["target_col"] == "a-02", "target_col"] = "1.03" # Respective powers and obligations of the European Union and of the Member States
    df.loc[df["target_col"] == "a-03", "target_col"] = "1.05" # EU law and national law
    df.loc[df["target_col"] == "a-04", "target_col"] = "1.06" # EU law and international law
    df.loc[df["target_col"] == "a-05", "target_col"] = "1.07" # Interpretation of EU law

    df.loc[df["target_col"] == "b-01", "target_col"] = "1.09" # Non-discrimination and citizenship of the Union
    df.loc[df["target_col"] == "b-02", "target_col"] = "4.02" # EEC/EC - Free movement of goods * Free movement of goods
    df.loc[df["target_col"] == "b-03", "target_col"] = "4.03" # Agriculture and fisheries 
    df.loc[df["target_col"] == "b-04", "target_col"] = "4.04" # EEC/EC - Free movement of persons and services * Free movement of persons and services
    df.loc[df["target_col"] == "b-05", "target_col"] = "4.05" # EEC/EC - Free movement of capital and freedom of payments * Free movement of capital and freedom of payments
    df.loc[df["target_col"] == "b-06", "target_col"] = "4.07" # EEC/EC - Transport * Transport
    df.loc[df["target_col"] == "b-07", "target_col"] = "4.08" # EEC/EC - Competition * Competition
    df.loc[df["target_col"] == "b-09", "target_col"] = "4.09" # EEC/EC - State aid * State aid
    df.loc[df["target_col"] == "b-10", "target_col"] = "4.10" # EEC/EC - Tax provisions * Tax provisions
    df.loc[df["target_col"] == "b-11", "target_col"] = "4.11" # Approximation of laws
    df.loc[df["target_col"] == "b-13", "target_col"] = "4.12" # EEC/EC - Economic and monetary policy * Economic and monetary policy
    df.loc[df["target_col"] == "b-14", "target_col"] = "6.02" # Commercial policy
    df.loc[df["target_col"] == "b-15", "target_col"] = "4.14" # EEC/EC - Social policy * Social policy
    df.loc[df["target_col"] == "b-17", "target_col"] = "5"    # EEC/EC - Association of Overseas Countries and Territories * Association of Overseas Countries and Territories
    df.loc[df["target_col"] == "b-18", "target_col"] = "2.01" # 2.01 Institutions, alternatively 2.02 Other EU bodies and agencies
    df.loc[df["target_col"] == "b-19", "target_col"] = "3"    # EEC/EC - Legal proceedings * Legal proceedings
    df.loc[df["target_col"] == "b-21", "target_col"] = "4.23" # Environment, sustainable development and climate
    df.loc[df["target_col"] == "b-22", "target_col"] = "2.06" # EEC/EC - Financial provisions * Financial provisions
    df.loc[df["target_col"] == "b-23", "target_col"] = "8"    # Accession of new Member States
    df.loc[df["target_col"] == "b-25", "target_col"] = "6.07" # International agreements
    df.loc[df["target_col"] == "b-29", "target_col"] = "4.19" # Trans-European networks
    df.loc[df["target_col"] == "b-30", "target_col"] = "6.03" # Development cooperation
    df.loc[df["target_col"] == "b-31", "target_col"] = "4.16" # Culture
    df.loc[df["target_col"] == "b-32", "target_col"] = "4.20" # Industry
    df.loc[df["target_col"] == "b-33", "target_col"] = "4.11" # Internal policy of the European Union / Approximation of laws / European Union trade mark 
    df.loc[df["target_col"] == "b-34", "target_col"] = "4.13" # EEC/EC - Employment * Employment
    df.loc[df["target_col"] == "b-35", "target_col"] = "4.17" # EEC/EC - Public health * Public health
    df.loc[df["target_col"] == "b-36", "target_col"] = "4.18" # EEC/EC - Consumer protection * Consumer protection
    df.loc[df["target_col"] == "b-37", "target_col"] = "4.22" # Research and technological development and space

    df.loc[df["target_col"] == "f-01", "target_col"] = "9.01" # The sources of European civil service law
    df.loc[df["target_col"] == "f-02", "target_col"] = "9.02" # General provisions of the Staff Regulations
    df.loc[df["target_col"] == "f-03", "target_col"] = "9.03" # Rights and obligations of officials
    df.loc[df["target_col"] == "f-04", "target_col"] = "9.08" # Recruitment
    df.loc[df["target_col"] == "f-05", "target_col"] = "9.09" # Administrative status of officials
    df.loc[df["target_col"] == "f-07", "target_col"] = "9.14" # Termination of service
    df.loc[df["target_col"] == "f-08", "target_col"] = "9.15" # Working conditions
    df.loc[df["target_col"] == "f-09", "target_col"] = "9.16" # Emoluments
    df.loc[df["target_col"] == "f-10", "target_col"] = "9.17" # Social security
    df.loc[df["target_col"] == "f-11", "target_col"] = "9.18" # Pensions
    df.loc[df["target_col"] == "f-12", "target_col"] = "9.19" # Recovery of undue payment
    df.loc[df["target_col"] == "f-13", "target_col"] = "9.20" # Subrogation of the European Union
    df.loc[df["target_col"] == "f-14", "target_col"] = "9.21" # Disciplinary measures
    df.loc[df["target_col"] == "f-15", "target_col"] = "9.22" # Administrative appeal procedure
    df.loc[df["target_col"] == "f-16", "target_col"] = "9.23" # Judicial proceedings
    df.loc[df["target_col"] == "f-18", "target_col"] = "9.25" # Conditions of employment of other servants of the European Union
    df.loc[df["target_col"] == "f-19", "target_col"] = "9.26" # Conditions of employment prior to the EEC/EAEC/EC Regulations
    df.loc[df["target_col"] == "f-20", "target_col"] = "9.27" # Other types of employment status

    df.loc[df["target_col"] == "g-02", "target_col"] = "6.01" # External policy / Common foreign and security policy (CFSP)
    df.loc[df["target_col"] == "g-03", "target_col"] = "4.06" # Internal policy of the European Union / Area of freedom, security and justice / Judicial cooperation in criminal matters



    return df

your_df = post_lisbon_dircode_mapper(your_df) 
your_df.head()
